# %%
import os
import matplotlib.pyplot as plt
import cv2
import dlib
import numpy as np

# %% [markdown]
# 1. Preparing picture

# %%
my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/face.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV
img_show = img_bgr.copy()      # copy
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# 2. Face detection

# %%
# detector
detector_hog = dlib.get_frontal_face_detector()

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)
print("complete")
# Out:
# complete

# %%
# face box list
print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()
# Out:
# rectangles[[(33, 504) (418, 889)]]

# %% [markdown]
# 3. face landmark

# %%
model_path = os.getenv('HOME')+'/aiffel/camera_sticker/models/shape_predictor_68_face_landmarks.dat'
landmark_predictor = dlib.shape_predictor(model_path)
print("complete")
# Out:
# complete

# %%
list_landmarks = []

# face landmark in each face
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    # saving face landmark location
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %% [markdown]
# 4. make a sticker!

# %%
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose's index
    x = landmark[30][0]
    y = landmark[30][1] + dlib_rect.height()//2 # middle point of face
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (230, 710)
# (x,y) : (230,903)
# (w,h) : (386,386)

# %%
sticker_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/kitty.png'
img_sticker = cv2.imread(sticker_path) # loading sticker image
img_sticker = cv2.resize(img_sticker, (w,h))
print (img_sticker.shape)
# Out:
# (386, 386, 3)

# %%
refined_x = x - w // 2
refined_y = y - h
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (37,517)

# %%
#sticker scale (to do not scale out of range)
if refined_x < 0: 
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0
if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (37,517)

# %%
#img_show[from:to] 
# sticker_area is crop part which will be applied the sticker from the original image.
sticker_area = img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)
print("complete")
# Out:
# complete

# %%
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 5. Remove bounding box and landmark

# %%
#So far, the bounding box and face landmark have been set using img_show, a copy of img_bgr. 
#Since all the locations are set, you can apply the sticker to the original img_bgr.

sticker_area = img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# 6. another cases

# %%
#mask

my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/mask.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV
img_show = img_bgr.copy()      # copy
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

detector_hog = dlib.get_frontal_face_detector()

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)

print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)

plt.imshow(img_show_rgb)
plt.show()

# It can't recognize face.
# Out:
# rectangles[]

# %%
#gliter
my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/gliter.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV
img_show = img_bgr.copy()      # copy
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

detector_hog = dlib.get_frontal_face_detector()

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)

print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)

model_path = os.getenv('HOME')+'/aiffel/camera_sticker/models/shape_predictor_68_face_landmarks.dat'
landmark_predictor = dlib.shape_predictor(model_path)

list_landmarks = []

# face landmark in each face
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    # saving face landmark location
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose's index
    x = landmark[30][0]
    y = landmark[30][1] + dlib_rect.height()//2 # middle point of face
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))

sticker_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/kitty.png'
img_sticker = cv2.imread(sticker_path) # loading sticker image
img_sticker = cv2.resize(img_sticker, (w,h))
print (img_sticker.shape)

refined_x = x - w // 2
refined_y = y - h
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))

#sticker scale (to do not scale out of range)
if refined_x < 0: 
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0
if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print ('(x,y) : (%d,%d)'%(refined_x, refined_y))

sticker_area = img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)

sticker_area = img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)

plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# complete!
# Out:
# rectangles[[(510, 724) (1469, 1682)]]
# (1032, 1234)
# (x,y) : (1032,1713)
# (w,h) : (960,960)
# (960, 960, 3)
# (x,y) : (552,753)
# (x,y) : (552,753)

# %%
#santa
my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/santa.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV
img_show = img_bgr.copy()      # copy
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

detector_hog = dlib.get_frontal_face_detector()

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)

print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)

model_path = os.getenv('HOME')+'/aiffel/camera_sticker/models/shape_predictor_68_face_landmarks.dat'
landmark_predictor = dlib.shape_predictor(model_path)

list_landmarks = []

# face landmark in each face
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    # saving face landmark location
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)

img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose's index
    x = landmark[30][0]
    y = landmark[30][1] + dlib_rect.height()//2 # middle point of face
    w = h = dlib_rect.width()
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))

sticker_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/kitty.png'
img_sticker = cv2.imread(sticker_path) # loading sticker image
img_sticker = cv2.resize(img_sticker, (w,h))
print (img_sticker.shape)

refined_x = x - w // 2
refined_y = y - h
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))

#sticker scale (to do not scale out of range)
if refined_x < 0: 
    img_sticker = img_sticker[:, -refined_x:]
    refined_x = 0
if refined_y < 0:
    img_sticker = img_sticker[-refined_y:, :]
    refined_y = 0

print ('(x,y) : (%d,%d)'%(refined_x, refined_y))

sticker_area = img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)

sticker_area = img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y +img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
    np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)

plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# It can't recognize my nose.
# Out:
# rectangles[]
# (960, 960, 3)
# (x,y) : (552,753)
# (x,y) : (552,753)

# %%
#hamster
my_image_path = os.getenv('HOME')+'/aiffel/camera_sticker/images/hamster.jpg'
img_bgr = cv2.imread(my_image_path)    # OpenCV
img_show = img_bgr.copy()      # copy
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

detector_hog = dlib.get_frontal_face_detector()

img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
dlib_rects = detector_hog(img_rgb, 1)   # (image, num of image pyramid)

print(dlib_rects)   

for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()

    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)

img_show_rgb =  cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)

plt.imshow(img_show_rgb)
plt.show()

# It can't recognize face.
# Out:
# rectangles[[(91, 1895) (199, 2003)]]

# %% [markdown]
# 7. Description

# %% [markdown]
# ### [problem 1] Even though the sticker is a png file, still the white background appears.

# %% [markdown]
# [sol 1]  "img_sticker!=0"
#
# Because Pixel intensity of black color(kitty) is 0.
#
# so, "np.where(img_sticker!=0,sticker_area,img_sticker).astype(np.uint8)" means,
#
# if the img_sticker !=0, using sticker_area(face),
#
# and in the ==0 (black) case, using img_sticker(kitty).

# %% [markdown]
# ### [problem 2] It must be the sticker located in the center of the face.

# %% [markdown]
# [sol 2] Sticker index y = landmark[30][1] + dlib_rect.height()//2 was set so that the sticker was placed in the middle of the face.
